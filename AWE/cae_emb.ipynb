# %%
import tensorflow as tf
from tensorflow.keras.layers import  LSTM, Dense, Flatten, Reshape
from tensorflow.keras.datasets import mnist
import numpy as np
import os
import _pickle as pickle
import argparse
import scipy.io.wavfile as wav
from python_speech_features import delta
from python_speech_features import mfcc
from tensorflow.keras.models import Model
import math
from tqdm import tqdm
from scipy.spatial.distance import cosine

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],[tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])
  except RuntimeError as e:
    print(e)
tf.compat.v1.logging.set_verbosity(40)
# Out:
# 2023-03-10 16:22:23.497655: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-10 16:22:27.934572: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda/lib64
# 2023-03-10 16:22:27.935345: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda/lib64
# 2023-03-10 16:22:27.935362: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
class Dataset(object):
    """Creat data class."""

    def __init__(self, wav_path, max_length=None):
        """Initialize dataset."""

        self.feature_dim = 39
        data, words = self.get_data(wav_path)
        self.data = data
        self.words = words
        uwords = np.unique(words)
        word2id = {v: k for k, v in enumerate(uwords)}
        self.id2word = {k: v for k, v in enumerate(uwords)}
        ids = [word2id[w] for w in words]

        self.ids = np.array(ids, dtype=np.int32)

        self.num_examples = len(self.ids)
        if max_length == None:
            self.max_length = np.max([len(self.data[x]) for x in range(0, self.num_examples-1)])
        else:
            self.max_length = max_length
    def get_data(self, wav_path):
        data = []
        labels = []
        for elt in os.listdir(wav_path):
            if ".wav" in elt:
                (rate, signal) = wav.read(wav_path+elt)
                mfcc_static = mfcc(signal, rate)
                mfcc_deltas = delta(mfcc_static, 2)
                mfcc_delta_deltas = delta(mfcc_deltas, 2)

                features = np.hstack([mfcc_static, mfcc_deltas, mfcc_delta_deltas])
                features = (features - np.mean(features, axis=0)) / np.std(features, axis=0)

                data.append(features)
                labels.append(elt)
                data_len = len(labels)

        return data, labels

    def batch(self, batch_size, max_length=None):
        self.tot_batch = self.num_examples//batch_size-1
        for batch_ind in range(0, self.num_examples, batch_size):
            temp_tens = []
            temp_label = []
            if batch_ind+batch_size>self.num_examples:
                end= batch_ind+batch_size- self.num_examples
            else:
                end = batch_ind+batch_size
            for data_ind in range(batch_ind, end):
#                 if batch_ind+batch_size<= len(self.data):
                
#                 else:
#                     max_length = np.max([len(self.data[x]) for x in range(batch_ind, len(self.data)-1)])
                paddings = tf.constant([[0, self.max_length-len(self.data[data_ind])], [0, 0]])
                padded = tf.pad(self.data[data_ind], paddings, "CONSTANT") 
                temp_tens.append(padded)
                temp_label.append(self.words[data_ind])
#             yield (tf.convert_to_tensor(temp_tens, dtype=tf.float32), tf.convert_to_tensor(temp_label, dtype=object))
            if len(temp_tens)>1:
                yield (tf.reshape(temp_tens, shape=(len(temp_tens),self.max_length, 39)))
    def batch_pairs(self, batch_size, max_length=None):
        self.tot_batch = self.num_examples//batch_size-1
        x_inp = []
        y_inp = []
        final_x = []
        final_y = []
        for ind_x, tens_x in enumerate(self.data):
            for ind_y, tens_y in enumerate(self.data[ind_x:]):
                if self.words[ind_x] == self.words[ind_y]:
                    x_inp.append(tens_x)
                    y_inp.append(tens_y)
        for batch_ind in range(0, len(x_inp), batch_size):
            temp_tens = []
            temp_label = []
            if batch_ind+batch_size>len(x_inp):
                end= batch_ind+batch_size- len(x_inp)
            else:
                end = batch_ind+batch_size
            for data_ind in range(batch_ind, end):

                paddings = tf.constant([[0, self.max_length-len(x_inp[data_ind])], [0, 0]])
                padded_x = tf.pad(x_inp[data_ind], paddings, "CONSTANT") 
                final_x.append(padded_x)
                paddings = tf.constant([[0, self.max_length-len(y_inp[data_ind])], [0, 0]])
                padded_y = tf.pad(y_inp[data_ind], paddings, "CONSTANT") 
                final_y.append(padded_y)
            if len(final_x)>1:
                yield (tf.reshape(final_x, shape=(len(final_x),self.max_length, 39)),tf.reshape(final_y, shape=(len(final_y),self.max_length, 39)))

    
    def get_batch_nb(self):
        return self.tot_batch
    
    def get_max_len(self):
        return self.max_length
    
    def batch_2(self):
        final = []
        
        for data_ind in range(0, self.num_examples):

            max_length = np.max([len(self.data[x]) for x in range(0, self.num_examples-1)])

            paddings = tf.constant([[0, max_length-len(self.data[data_ind])], [0, 0]])
            
            padded = tf.pad(self.data[data_ind], paddings, "CONSTANT") 
            
            final.append(padded)

        x_inp = np.asarray([x for x in final if np.mean(x) !=0 and not math.isnan(np.mean(x))])
        return x_inp

# %%
train_dataset = Dataset("/home/getalp/leferrae/post_doc/corpora/cv-corpus-12.0-2022-12-07/pt/trainWords/")
print(train_dataset.get_max_len())
# test_dataset = Dataset("/home/getalp/leferrae/post_doc/corpora/cv-corpus-12.0-2022-12-07/pt/devWords/")

# train_dataset = Dataset("/home/getalp/leferrae/post_doc/corpora/guinee_casa/train/")
# test_dataset = Dataset("/home/getalp/leferrae/post_doc/corpora/guinee_casa/dev/")
# Out:
# 193

# %%
test_dataset = Dataset("/home/getalp/leferrae/post_doc/corpora/cv-corpus-12.0-2022-12-07/pt/devWords/", max_length = train_dataset.get_max_len())

# %%
print(train_dataset.batch_2().shape)
# Out:
# 2023-03-08 16:17:00.743781: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-08 16:17:02.429296: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5120 MB memory:  -> device: 0, name: Quadro P6000, pci bus id: 0000:04:00.0, compute capability: 6.1
# 2023-03-08 16:17:02.432873: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 10493 MB memory:  -> device: 1, name: Quadro P6000, pci bus id: 0000:82:00.0, compute capability: 6.1
# (3150, 193, 39)

# %%
class Autoencoder(Model):
  def __init__(self, latent_dim):
    super(Autoencoder, self).__init__()
    self.latent_dim = latent_dim   
    self.encoder = tf.keras.Sequential([
      LSTM(latent_dim, activation='relu', return_sequences=True),
      LSTM(latent_dim, activation='relu', return_sequences=True),
      LSTM(latent_dim, activation='relu'),
    ])
    self.decoder = tf.keras.Sequential([
      Dense(7527, activation='sigmoid'),
      Reshape((193, 39))
    ])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded
  def make_emb(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return encoded

# %%
latent_dim = 64 

class Autoencoder(Model):
  def __init__(self, latent_dim):
    super(Autoencoder, self).__init__()
    self.latent_dim = latent_dim   
    self.encoder = tf.keras.Sequential([
      Flatten(),
      Dense(latent_dim, activation='relu', return_sequences=True),
    ])
    self.decoder = tf.keras.Sequential([
      Dense(7527, activation='sigmoid', return_sequences=True),
      Reshape((193, 39))
    ])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = Autoencoder(latent_dim)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [25], line 21
#      18     decoded = self.decoder(encoded)
#      19     return decoded
# ---> 21 autoencoder = Autoencoder(latent_dim)
#
# Cell In [25], line 9, in Autoencoder.__init__(self, latent_dim)
#       5 super(Autoencoder, self).__init__()
#       6 self.latent_dim = latent_dim
#       7 self.encoder = tf.keras.Sequential([
#       8   Flatten(),
# ----> 9   Dense(latent_dim, activation='relu', return_sequences=True),
#      10 ])
#      11 self.decoder = tf.keras.Sequential([
#      12   Dense(7527, activation='sigmoid', return_sequences=True),
#      13   Reshape((193, 39))
#      14 ])
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/dtensor/utils.py:96, in allow_initializer_layout.<locals>._wrap_function(layer_instance, *args, **kwargs)
#      93         if layout:
#      94             layout_args[variable_name + "_layout"] = layout
# ---> 96 init_method(layer_instance, *args, **kwargs)
#      98 # Inject the layout parameter after the invocation of __init__()
#      99 for layout_param_name, layout in layout_args.items():
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/layers/core/dense.py:117, in Dense.__init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     102 @utils.allow_initializer_layout
#     103 def __init__(
#     104     self,
#    (...)
#     115     **kwargs,
#     116 ):
# --> 117     super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#     119     self.units = int(units) if not isinstance(units, int) else units
#     120     if self.units < 0:
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/tensorflow/python/trackable/base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/engine/base_layer.py:340, in Layer.__init__(self, trainable, name, dtype, dynamic, **kwargs)
#     329 allowed_kwargs = {
#     330     "input_dim",
#     331     "input_shape",
#    (...)
#     337     "implementation",
#     338 }
#     339 # Validate optional keyword arguments.
# --> 340 generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#     342 # Mutable properties
#     343 # Indicates whether the layer's weights are updated during training
#     344 # and whether the layer's updates are run during training.
#     345 if not (
#     346     isinstance(trainable, bool)
#     347     or (
#    (...)
#     350     )
#     351 ):
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/utils/generic_utils.py:515, in validate_kwargs(kwargs, allowed_kwargs, error_message)
#     513 for kwarg in kwargs:
#     514     if kwarg not in allowed_kwargs:
# --> 515         raise TypeError(error_message, kwarg)
#
# TypeError: ('Keyword argument not understood:', 'return_sequences')

# %%
loss = tf.keras.losses.MeanSquaredError()
def grad(model, inputs, outputs):
    with tf.GradientTape() as tape:
        out = model(inputs)
        loss_value = loss(outputs, out)
    return loss_value, tape.gradient(loss_value, model.trainable_variables), inputs, out

# %%
autoencoder = Autoencoder(64)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
# autoencoder.save_weights("./models/AE_{}_ckpt/ae_rand_model.ckpt".format(rep), overwrite=True)
global_step = tf.Variable(0)
n_epochs = 15
# Out:
# 2023-03-10 16:23:26.216344: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-10 16:23:29.197759: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5120 MB memory:  -> device: 0, name: Quadro P6000, pci bus id: 0000:04:00.0, compute capability: 6.1
# 2023-03-10 16:23:29.201146: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 11055 MB memory:  -> device: 1, name: Quadro P6000, pci bus id: 0000:82:00.0, compute capability: 6.1

# %%
autoencoder.compile(optimizer=optimizer, loss=tf.keras.losses.MeanSquaredError())
autoencoder.build((None,193, 39))
autoencoder.summary()
print(np.array(train_dataset.batch_2()).shape)
# autoencoder.fit(train_dataset.batch_2(), train_dataset.batch_2(),
#             epochs=10,
#             shuffle=True,
#             validation_data=(test_dataset.batch_2(), test_dataset.batch_2()))
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 64)                92672
#
#  sequential_1 (Sequential)   (None, 193, 39)           489255
#
# =================================================================
# Total params: 581,927
# Trainable params: 581,927
# Non-trainable params: 0
# _________________________________________________________________
# (3150, 193, 39)

# %%
autoencoder.fit(train_dataset.batch_2(), train_dataset.batch_2(),
            epochs=10,
            shuffle=True,
            validation_data=(test_dataset.batch_2(), test_dataset.batch_2()))
# Out:
# Epoch 1/10
# 2023-03-07 09:15:48.117096: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7fb4800192e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-03-07 09:15:48.117152: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): Quadro P6000, Compute Capability 6.1
# 2023-03-07 09:15:48.117166: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (1): Quadro P6000, Compute Capability 6.1
# 2023-03-07 09:15:48.123862: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-03-07 09:15:48.386383: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-03-07 09:15:48.460664: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 99/99 [==============================] - 78s 738ms/step - loss: 0.7543 - val_loss: 0.6608
# Epoch 2/10
# 99/99 [==============================] - 72s 730ms/step - loss: 0.7476 - val_loss: 0.6542
# Epoch 3/10
# 99/99 [==============================] - 72s 731ms/step - loss: 0.7415 - val_loss: 0.6481
# Epoch 4/10
# 99/99 [==============================] - 73s 739ms/step - loss: 0.7356 - val_loss: 0.6423
# Epoch 5/10
# 99/99 [==============================] - 73s 741ms/step - loss: 0.7298 - val_loss: 0.6367
# Epoch 6/10
# 99/99 [==============================] - 74s 750ms/step - loss: 0.7242 - val_loss: 0.6312
# Epoch 7/10
# 99/99 [==============================] - 75s 757ms/step - loss: 0.7188 - val_loss: 0.6258
# Epoch 8/10
# 99/99 [==============================] - 74s 749ms/step - loss: 0.7134 - val_loss: 0.6205
# Epoch 9/10
# 99/99 [==============================] - 79s 795ms/step - loss: 0.7082 - val_loss: 0.6154
# Epoch 10/10
# 99/99 [==============================] - 73s 735ms/step - loss: 0.7031 - val_loss: 0.6103

# %%
import sys

def print_progress_bar(index, total, label):
    n_bar = 50  # Progress bar width
    progress = index / total
    sys.stdout.write('\r')
    sys.stdout.write(f"[{'=' * int(n_bar * progress):{n_bar}s}] {int(100 * progress)}%  {label}")
    sys.stdout.flush()

# %%
def eval_QbE(model, max_length):
    queries = {}
    test = {}
    results = {}
    rootTest = "/home/getalp/leferrae/post_doc/classifier_zing/wordsTest/"
    rootQueries = "/home/getalp/leferrae/post_doc/corpora/guinee_casa/queries/"
    temp_emb = []
    temp_labels = []
    for elt in tqdm(os.listdir(rootQueries)):
        if ".wav" in elt:
            (rate, signal) = wav.read(rootQueries+elt)
            mfcc_static = mfcc(signal, rate)
            mfcc_deltas = delta(mfcc_static, 2)
            mfcc_delta_deltas = delta(mfcc_deltas, 2)
            features = np.hstack([mfcc_static, mfcc_deltas, mfcc_delta_deltas])
            features = (features - np.mean(features, axis=0)) / np.std(features, axis=0)
            if len(features)>max_length:
                tooMuch = len(features)-max_length
                startTrunc = tooMuch//2
                endTruc = tooMuch//2+tooMuch%2
                padded = tf.constant(features[startTrunc:-endTrunc])
            else:
                paddings = tf.constant([[0, max_length-len(features)], [0, 0]])
                padded = tf.pad(features, paddings, "CONSTANT") 
            temp_emb.append(padded)
            temp_labels.append(elt.replace(".wav", ""))
            
    embeddings = model.make_emb(tf.reshape(temp_emb, shape=(len(temp_emb),max_length, 39)))
                                
    for i, emb in enumerate(embeddings):
        queries[temp_labels[i]] = emb
    
    temp_emb = []
    temp_labels = []
    for elt in tqdm(os.listdir(rootTest)):
        (rate, signal) = wav.read(rootTest+elt)
        mfcc_static = mfcc(signal, rate)
        mfcc_deltas = delta(mfcc_static, 2)
        mfcc_delta_deltas = delta(mfcc_deltas, 2)
        temp_labels.append(elt)
        features = np.hstack([mfcc_static, mfcc_deltas, mfcc_delta_deltas])
        features = (features - np.mean(features, axis=0)) / np.std(features, axis=0)
        if len(features)>max_length:
            tooMuch = len(features)-max_length
            startTrunc = tooMuch//2
            endTrunc = tooMuch//2+tooMuch%2
            padded = tf.constant(features[startTrunc:-endTrunc])
        else:
            paddings = tf.constant([[0, max_length-len(features)], [0, 0]])
            padded = tf.pad(features, paddings, "CONSTANT") 
        temp_emb.append(padded)
#     embeddings = model.make_emb(tf.reshape(temp_emb, shape=(len(temp_emb),max_length, 39)))
    embeddings = model.make_emb(tf.reshape(temp_emb, shape=(len(temp_emb),max_length, 39)))
    for i, emb in enumerate(embeddings):
        elt = temp_labels[i]
        queries[elt.replace(".wav", "")] = emb
        name = elt.split("_")[0]
        test[elt.replace(".wav", "")] = {"embedding" : emb, "label" : name}
    for testWord in test:
        scores = []
        for query in queries:
            score = cosine(test[testWord]["embedding"][0], queries[query][0])
            scores.append((query, score))
        scores.sort(key=lambda x : x[1])
        results[testWord] = scores
    top1 = 0
    top2 = 0
    top5 = 0
    tot = 0
    for elt in results:
        tot+=1
        name = elt.split("_")[0]
        list2 = [x[0] for x in results[elt][:2]]
        list5 = [x[0] for x in results[elt][:5]]

        if name == results[elt][0][0]:
            top1+=1
        if name in list2:
            top2+=1
        if name in list5:
            top5+=1
    print("\n",top1/tot*100, top2/tot*100, top5/tot*100)

# %%
for epoch in range(10):
    print("\nEpoch: ", epoch)

    batch_id = 0
    val_losses=[]
    
    for index, x in enumerate(test_dataset.batch(batch_size=300)):
        loss_value, grads, inputs, reconstruction = grad(autoencoder, x, x)
        print_progress_bar(index, test_dataset.get_batch_nb(), loss_value)
        val_losses.append(loss_value)
    print("\nvalidation loss : {}".format(np.mean(val_losses)))
    for index, x in enumerate(train_dataset.batch(batch_size=32)):
        
        loss_value, grads, inputs, reconstruction = grad(autoencoder, x, x)
        optimizer.apply_gradients(zip(grads, autoencoder.trainable_variables),
                            global_step)
        print_progress_bar(index, train_dataset.get_batch_nb()+1, loss_value)
        batch_id +=1
    eval_QbE(autoencoder, train_dataset.get_max_len())
# Out:
# Epoch:  0
# [==================================================] 100%  0.5691549181938171
# validation loss : 0.5757984519004822
# [================================================= ] 98%  0.5716627836227417
# 100%|██████████████████████████████████████████| 21/21 [00:00<00:00, 206.80it/s]
# 100%|████████████████████████████████████████| 140/140 [00:00<00:00, 217.86it/s]
#  2.142857142857143 2.142857142857143 5.0
#
# Epoch:  1
# [==================================================] 100%  0.5646073818206787
# validation loss : 0.5712370276451111
# [================================================= ] 98%  0.5672261118888855
# 100%|██████████████████████████████████████████| 21/21 [00:00<00:00, 220.23it/s]
# 100%|████████████████████████████████████████| 140/140 [00:00<00:00, 270.05it/s]
#  2.142857142857143 2.142857142857143 5.0
#
# Epoch:  2
# [==================================================] 100%  0.5601686835289001
# validation loss : 0.5667847394943237
# [================================================= ] 98%  0.5628955364227295
# 100%|██████████████████████████████████████████| 21/21 [00:00<00:00, 228.73it/s]
# 100%|████████████████████████████████████████| 140/140 [00:00<00:00, 247.45it/s]
#  2.142857142857143 2.142857142857143 5.0
#
# Epoch:  3
# [==================================================] 100%  0.5558388829231262
# validation loss : 0.5624415278434753
# [================================================= ] 98%  0.5586711764335632
# 100%|██████████████████████████████████████████| 21/21 [00:00<00:00, 228.47it/s]
# 100%|████████████████████████████████████████| 140/140 [00:00<00:00, 215.52it/s]
#  2.142857142857143 2.142857142857143 5.0
#
# Epoch:  4
# [==================================================] 100%  0.5516175627708435
# validation loss : 0.5582073330879211
# [================================================= ] 98%  0.5545524358749391
# 100%|██████████████████████████████████████████| 21/21 [00:00<00:00, 226.84it/s]
# 100%|████████████████████████████████████████| 140/140 [00:00<00:00, 223.21it/s]
#  2.142857142857143 2.142857142857143 5.0
#
# Epoch:  5
# [==================================================] 100%  0.5475039482116699
# validation loss : 0.5540812611579895
# [=============                                     ] 27%  0.6677919626235962
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [94], line 14
#      11 print("\nvalidation loss : {}".format(np.mean(val_losses)))
#      12 for index, x in enumerate(train_dataset.batch(batch_size=32)):
# ---> 14     loss_value, grads, inputs, reconstruction = grad(autoencoder, x)
#      15     optimizer.apply_gradients(zip(grads, autoencoder.trainable_variables),
#      16                         global_step)
#      17     print_progress_bar(index, train_dataset.get_batch_nb()+1, loss_value)
#
# Cell In [46], line 4, in grad(model, inputs)
#       2 def grad(model, inputs):
#       3     with tf.GradientTape() as tape:
# ----> 4         out = model(inputs)
#       5         loss_value = loss(inputs, out)
#       6     return loss_value, tape.gradient(loss_value, model.trainable_variables), inputs, out
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/engine/training.py:561, in Model.__call__(self, *args, **kwargs)
#     557         super().__call__(inputs, *copied_args, **copied_kwargs)
#     559     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 561 return super().__call__(*args, **kwargs)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/engine/base_layer.py:1132, in Layer.__call__(self, *args, **kwargs)
#    1127     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1129 with autocast_variable.enable_auto_cast_variables(
#    1130     self._compute_dtype_object
#    1131 ):
# -> 1132     outputs = call_fn(inputs, *args, **kwargs)
#    1134 if self._activity_regularizer:
#    1135     self._handle_activity_regularization(inputs, outputs)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# Cell In [45], line 16, in Autoencoder.call(self, x)
#      15 def call(self, x):
# ---> 16   encoded = self.encoder(x)
#      17   decoded = self.decoder(encoded)
#      18   return decoded
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/engine/training.py:561, in Model.__call__(self, *args, **kwargs)
#     557         super().__call__(inputs, *copied_args, **copied_kwargs)
#     559     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 561 return super().__call__(*args, **kwargs)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/engine/base_layer.py:1132, in Layer.__call__(self, *args, **kwargs)
#    1127     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1129 with autocast_variable.enable_auto_cast_variables(
#    1130     self._compute_dtype_object
#    1131 ):
# -> 1132     outputs = call_fn(inputs, *args, **kwargs)
#    1134 if self._activity_regularizer:
#    1135     self._handle_activity_regularization(inputs, outputs)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/engine/sequential.py:413, in Sequential.call(self, inputs, training, mask)
#     411     if not self.built:
#     412         self._init_graph_network(self.inputs, self.outputs)
# --> 413     return super().call(inputs, training=training, mask=mask)
#     415 outputs = inputs  # handle the corner case where self.layers is empty
#     416 for layer in self.layers:
#     417     # During each iteration, `inputs` are the inputs to `layer`, and
#     418     # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     419     # end of each iteration `inputs` is set to `outputs` to prepare for
#     420     # the next layer.
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/engine/functional.py:511, in Functional.call(self, inputs, training, mask)
#     492 @doc_controls.do_not_doc_inheritable
#     493 def call(self, inputs, training=None, mask=None):
#     494     """Calls the model on new inputs.
#     495
#     496     In this case `call` just reapplies
#    (...)
#     509         a list of tensors if there are more than one outputs.
#     510     """
# --> 511     return self._run_internal_graph(inputs, training=training, mask=mask)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/engine/functional.py:668, in Functional._run_internal_graph(self, inputs, training, mask)
#     665     continue  # Node is not computable, try skipping.
#     667 args, kwargs = node.map_arguments(tensor_dict)
# --> 668 outputs = node.layer(*args, **kwargs)
#     670 # Update tensor_dict.
#     671 for x_id, y in zip(
#     672     node.flat_output_ids, tf.nest.flatten(outputs)
#     673 ):
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/layers/rnn/base_rnn.py:556, in RNN.__call__(self, inputs, initial_state, constants, **kwargs)
#     551 inputs, initial_state, constants = rnn_utils.standardize_args(
#     552     inputs, initial_state, constants, self._num_constants
#     553 )
#     555 if initial_state is None and constants is None:
# --> 556     return super().__call__(inputs, **kwargs)
#     558 # If any of `initial_state` or `constants` are specified and are Keras
#     559 # tensors, then add them to the inputs and temporarily modify the
#     560 # input_spec to include them.
#     562 additional_inputs = []
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/engine/base_layer.py:1132, in Layer.__call__(self, *args, **kwargs)
#    1127     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1129 with autocast_variable.enable_auto_cast_variables(
#    1130     self._compute_dtype_object
#    1131 ):
# -> 1132     outputs = call_fn(inputs, *args, **kwargs)
#    1134 if self._activity_regularizer:
#    1135     self._handle_activity_regularization(inputs, outputs)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/layers/rnn/lstm.py:625, in LSTM.call(self, inputs, mask, training, initial_state)
#     622     def step(inputs, states):
#     623         return self.cell(inputs, states, **kwargs)
# --> 625     last_output, outputs, states = backend.rnn(
#     626         step,
#     627         inputs,
#     628         initial_state,
#     629         constants=None,
#     630         go_backwards=self.go_backwards,
#     631         mask=mask,
#     632         unroll=self.unroll,
#     633         input_length=row_lengths
#     634         if row_lengths is not None
#     635         else timesteps,
#     636         time_major=self.time_major,
#     637         zero_output_for_mask=self.zero_output_for_mask,
#     638         return_all_outputs=self.return_sequences,
#     639     )
#     640     runtime = gru_lstm_utils.runtime(gru_lstm_utils.RUNTIME_UNKNOWN)
#     641 else:
#     642     # Use the new defun approach for backend implementation swap.
#     643     # Note that different implementations need to have same function
#     644     # signature, eg, the tensor parameters need to have same shape and
#     645     # dtypes. Since the cuDNN has an extra set of bias, those bias will
#     646     # be passed to both normal and cuDNN implementations.
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/backend.py:5142, in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask, return_all_outputs)
#    5137         new_states = tf.nest.pack_sequence_as(
#    5138             initial_states, flat_new_state
#    5139         )
#    5140         return (time + 1, output_ta_t) + tuple(new_states)
# -> 5142     final_outputs = tf.compat.v1.while_loop(
#    5143         body=_step,
#    5144         loop_vars=(time, output_ta) + states,
#    5145         **while_loop_kwargs,
#    5146     )
#    5147     new_states = final_outputs[2:]
#    5149 output_ta = final_outputs[1]
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/tensorflow/python/ops/control_flow_ops.py:2765, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2762 loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#    2763                                         list(loop_vars))
#    2764 while cond(*loop_vars):
# -> 2765   loop_vars = body(*loop_vars)
#    2766   if try_to_pack and not isinstance(loop_vars, (list, _basetuple)):
#    2767     packed = True
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/backend.py:5121, in rnn.<locals>._step(time, output_ta_t, *states)
#    5119 current_input = tuple(ta.read(time) for ta in input_ta)
#    5120 current_input = tf.nest.pack_sequence_as(inputs, current_input)
# -> 5121 output, new_states = step_function(
#    5122     current_input, tuple(states) + tuple(constants)
#    5123 )
#    5124 flat_state = tf.nest.flatten(states)
#    5125 flat_new_state = tf.nest.flatten(new_states)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/layers/rnn/lstm.py:623, in LSTM.call.<locals>.step(inputs, states)
#     622 def step(inputs, states):
# --> 623     return self.cell(inputs, states, **kwargs)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/engine/base_layer.py:1132, in Layer.__call__(self, *args, **kwargs)
#    1127     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1129 with autocast_variable.enable_auto_cast_variables(
#    1130     self._compute_dtype_object
#    1131 ):
# -> 1132     outputs = call_fn(inputs, *args, **kwargs)
#    1134 if self._activity_regularizer:
#    1135     self._handle_activity_regularization(inputs, outputs)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/layers/rnn/lstm.py:327, in LSTMCell.call(self, inputs, states, training)
#     325 if 0.0 < self.dropout < 1.0:
#     326     inputs = inputs * dp_mask[0]
# --> 327 z = backend.dot(inputs, self.kernel)
#     328 z += backend.dot(h_tm1, self.recurrent_kernel)
#     329 if self.use_bias:
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/backend.py:2428, in dot(x, y)
#    2389 @keras_export("keras.backend.dot")
#    2390 @tf.__internal__.dispatch.add_dispatch_support
#    2391 @doc_controls.do_not_generate_docs
#    2392 def dot(x, y):
#    2393     """Multiplies 2 tensors (and/or variables) and returns a tensor.
#    2394
#    2395     This operation corresponds to `numpy.dot(a, b, out=None)`.
#    (...)
#    2426     (2, 4, 5)
#    2427     """
# -> 2428     if ndim(x) is not None and (ndim(x) > 2 or ndim(y) > 2):
#    2429         x_shape = []
#    2430         for i, s in zip(int_shape(x), tf.unstack(tf.shape(x))):
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/keras/backend.py:1564, in ndim(x)
#    1541 @keras_export("keras.backend.ndim")
#    1542 @doc_controls.do_not_generate_docs
#    1543 def ndim(x):
#    1544     """Returns the number of axes in a tensor, as an integer.
#    1545
#    1546     Args:
#    (...)
#    1562
#    1563     """
# -> 1564     return x.shape.rank
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:1259, in _EagerTensorBase.shape(self)
#    1254 if self._tensor_shape is None:  # pylint: disable=access-member-before-definition
#    1255   # pylint: disable=protected-access
#    1256   try:
#    1257     # `_tensor_shape` is declared and defined in the definition of
#    1258     # `EagerTensor`, in C.
# -> 1259     self._tensor_shape = tensor_shape.TensorShape(self._shape_tuple())
#    1260   except core._NotOkStatusException as e:
#    1261     raise core._status_to_exception(e) from None
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/tensorflow/python/framework/tensor_shape.py:774, in TensorShape.__init__(self, dims)
#     765 """Creates a new TensorShape with the given dimensions.
#     766
#     767 Args:
#    (...)
#     771   TypeError: If dims cannot be converted to a list of dimensions.
#     772 """
#     773 if isinstance(dims, (tuple, list)):  # Most common case.
# --> 774   self._dims = tuple(as_dimension(d).value for d in dims)
#     775 elif dims is None:
#     776   self._dims = None
#
# KeyboardInterrupt:

# %%
for epoch in range(10):
    print("\nEpoch: ", epoch)

    batch_id = 0

    for index, tup_d in enumerate(train_dataset.batch_pairs(batch_size=16)):
        x,y = tup_d[0], tup_d[1]

        loss_value, grads, inputs, reconstruction = grad(autoencoder, x, y)
        optimizer.apply_gradients(zip(grads, autoencoder.trainable_variables),
                            global_step)
        print_progress_bar(index, train_dataset.get_batch_nb()+1, loss_value)
        batch_id +=1
    eval_QbE(autoencoder, train_dataset.get_max_len())
# Out:
# Epoch:  0
# [=                                                 ] 2%  1.0413181781768799ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x7f1bac43caf0>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "/home/getalp/leferrae/miniconda3/envs/py38/lib/python3.8/site-packages/keras/backend.py", line 5133, in <genexpr>
#     ta.write(ta_index_to_write, out)  File "/home/getalp/leferrae/miniconda3/envs/py38/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py", line 243, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs),
# ==================================
# [===================                               ] 39%  0.7710629105567932
# 2023-03-10 16:39:16.640972: W tensorflow/tsl/framework/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 37.21MiB (rounded to 39020032)requested by op RealDiv
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-03-10 16:39:16.643321: I tensorflow/tsl/framework/bfc_allocator.cc:1034] BFCAllocator dump for GPU_0_bfc
# 2023-03-10 16:39:16.643440: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (256): 	Total Chunks: 23, Chunks in use: 23. 5.8KiB allocated for chunks. 5.8KiB in use in bin. 104B client-requested in use in bin.
# 2023-03-10 16:39:16.643459: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-03-10 16:39:16.643477: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (1024): 	Total Chunks: 17, Chunks in use: 13. 17.8KiB allocated for chunks. 13.8KiB in use in bin. 13.0KiB client-requested in use in bin.
# 2023-03-10 16:39:16.643491: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (2048): 	Total Chunks: 3, Chunks in use: 0. 6.2KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-03-10 16:39:16.643503: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-03-10 16:39:16.643519: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (8192): 	Total Chunks: 1, Chunks in use: 0. 13.0KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-03-10 16:39:16.643543: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (16384): 	Total Chunks: 1, Chunks in use: 1. 29.5KiB allocated for chunks. 29.5KiB in use in bin. 29.4KiB client-requested in use in bin.
# 2023-03-10 16:39:16.643575: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (32768): 	Total Chunks: 2396, Chunks in use: 2389. 137.84MiB allocated for chunks. 137.54MiB in use in bin. 137.03MiB client-requested in use in bin.
# 2023-03-10 16:39:16.643605: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (65536): 	Total Chunks: 230, Chunks in use: 230. 18.32MiB allocated for chunks. 18.32MiB in use in bin. 13.31MiB client-requested in use in bin.
# 2023-03-10 16:39:16.643629: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-03-10 16:39:16.643656: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (262144): 	Total Chunks: 6947, Chunks in use: 6940. 2.15GiB allocated for chunks. 2.14GiB in use in bin. 2.14GiB client-requested in use in bin.
# 2023-03-10 16:39:16.643707: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (524288): 	Total Chunks: 13, Chunks in use: 10. 8.06MiB allocated for chunks. 6.15MiB in use in bin. 3.80MiB client-requested in use in bin.
# 2023-03-10 16:39:16.643731: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (1048576): 	Total Chunks: 1161, Chunks in use: 1160. 1.44GiB allocated for chunks. 1.44GiB in use in bin. 1.43GiB client-requested in use in bin.
# 2023-03-10 16:39:16.643755: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (2097152): 	Total Chunks: 5, Chunks in use: 3. 12.58MiB allocated for chunks. 7.00MiB in use in bin. 4.37MiB client-requested in use in bin.
# 2023-03-10 16:39:16.643781: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (4194304): 	Total Chunks: 1, Chunks in use: 0. 5.38MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-03-10 16:39:16.643805: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-03-10 16:39:16.643830: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-03-10 16:39:16.643863: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (33554432): 	Total Chunks: 13, Chunks in use: 13. 649.32MiB allocated for chunks. 649.32MiB in use in bin. 543.87MiB client-requested in use in bin.
# 2023-03-10 16:39:16.643893: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (67108864): 	Total Chunks: 4, Chunks in use: 4. 335.31MiB allocated for chunks. 335.31MiB in use in bin. 275.65MiB client-requested in use in bin.
# 2023-03-10 16:39:16.643919: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (134217728): 	Total Chunks: 2, Chunks in use: 2. 280.64MiB allocated for chunks. 280.64MiB in use in bin. 148.85MiB client-requested in use in bin.
# 2023-03-10 16:39:16.643940: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-03-10 16:39:16.643983: I tensorflow/tsl/framework/bfc_allocator.cc:1057] Bin for 37.21MiB was 32.00MiB, Chunk State:
# 2023-03-10 16:39:16.644005: I tensorflow/tsl/framework/bfc_allocator.cc:1070] Next region of size 5368709120
# 2023-03-10 16:39:16.644041: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f19c0000000 of size 256 next 1
# 2023-03-10 16:39:16.644071: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f19c0000100 of size 1280 next 2
# 2023-03-10 16:39:16.644094: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f19c0000600 of size 256 next 3
# 2023-03-10 16:39:16.644118: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f19c0000700 of size 256 next 4
# 2023-03-10 16:39:16.644138: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f19c0000800 of size 256 next 5
# 2023-03-10 16:39:16.644161: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f19c0000900 of size 256 next 6
# 2023-03-10 16:39:16.644182: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f19c0000a00 of size 256 next 7
# 2023-03-10 16:39:16.644205: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f19c0000b00 of size 256 next 8
# 2023-03-10 16:39:16.644251: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f19c0000c00 of size 256 next 9
# 2023-03-10 16:39:16.644276: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f19c0000d00 of size 256 next 11
# 2023-03-10 16:39:16.644298: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f19c0000e00 of size 256 next 12
# 2023-03-10 16:39:16.644321: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f19c0000f00 of size 256 next 13
# 2023-03-10 16:39:16.644343: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f19c0
I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 1646592 totalling 1.57MiB
# 2023-03-10 16:39:16.771493: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 1824768 totalling 1.74MiB
# 2023-03-10 16:39:16.771498: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 2 Chunks of size 1926912 totalling 3.67MiB
# 2023-03-10 16:39:16.771503: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 1966080 totalling 1.88MiB
# 2023-03-10 16:39:16.771509: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 1990656 totalling 1.90MiB
# 2023-03-10 16:39:16.771514: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 2382080 totalling 2.27MiB
# 2023-03-10 16:39:16.771519: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 2455552 totalling 2.34MiB
# 2023-03-10 16:39:16.771524: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 2505728 totalling 2.39MiB
# 2023-03-10 16:39:16.771529: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 2 Chunks of size 39020032 totalling 74.42MiB
# 2023-03-10 16:39:16.771534: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 42392064 totalling 40.43MiB
# 2023-03-10 16:39:16.771539: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 43479040 totalling 41.46MiB
# 2023-03-10 16:39:16.771544: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 46830592 totalling 44.66MiB
# 2023-03-10 16:39:16.771549: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 49404416 totalling 47.12MiB
# 2023-03-10 16:39:16.771554: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 52232192 totalling 49.81MiB
# 2023-03-10 16:39:16.771559: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 53030912 totalling 50.57MiB
# 2023-03-10 16:39:16.771564: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 60115712 totalling 57.33MiB
# 2023-03-10 16:39:16.771570: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 63242240 totalling 60.31MiB
# 2023-03-10 16:39:16.771575: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 3 Chunks of size 64032768 totalling 183.20MiB
# 2023-03-10 16:39:16.771581: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 69566464 totalling 66.34MiB
# 2023-03-10 16:39:16.771586: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 87131136 totalling 83.09MiB
# 2023-03-10 16:39:16.771591: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 92527616 totalling 88.24MiB
# 2023-03-10 16:39:16.771595: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 102375424 totalling 97.63MiB
# 2023-03-10 16:39:16.771601: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 146407424 totalling 139.62MiB
# 2023-03-10 16:39:16.771606: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 147861504 totalling 141.01MiB
# 2023-03-10 16:39:16.771611: I tensorflow/tsl/framework/bfc_allocator.cc:1102] Sum Total of in-use chunks: 4.98GiB
# 2023-03-10 16:39:16.771616: I tensorflow/tsl/framework/bfc_allocator.cc:1104] total_region_allocated_bytes_: 5368709120 memory_limit_: 5368709120 available bytes: 0 curr_region_allocation_bytes_: 10737418240
# 2023-03-10 16:39:16.771629: I tensorflow/tsl/framework/bfc_allocator.cc:1110] Stats:
# Limit:                      5368709120
# InUse:                      5350405376
# MaxInUse:                   5350405376
# NumAllocs:                     2727092
# MaxAllocSize:                147861504
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-03-10 16:39:16.773964: W tensorflow/tsl/framework/bfc_allocator.cc:492] **********************x*****************************************************************************
# 2023-03-10 16:39:16.774104: W tensorflow/core/framework/op_kernel.cc:1818] RESOURCE_EXHAUSTED: failed to allocate memory
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In [17], line 9
#       6 for index, tup_d in enumerate(train_dataset.batch_pairs(batch_size=16)):
#       7     x,y = tup_d[0], tup_d[1]
# ----> 9     loss_value, grads, inputs, reconstruction = grad(autoencoder, x, y)
#      10     optimizer.apply_gradients(zip(grads, autoencoder.trainable_variables),
#      11                         global_step)
#      12     print_progress_bar(index, train_dataset.get_batch_nb()+1, loss_value)
#
# Cell In [14], line 6, in grad(model, inputs, outputs)
#       4     out = model(inputs)
#       5     loss_value = loss(outputs, out)
# ----> 6 return loss_value, tape.gradient(loss_value, model.trainable_variables), inputs, out
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/tensorflow/python/eager/backprop.py:1112, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1106   output_gradients = (
#    1107       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1108           output_gradients))
#    1109   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1110                       for x in output_gradients]
# -> 1112 flat_grad = imperative_grad.imperative_grad(
#    1113     self._tape,
#    1114     flat_targets,
#    1115     flat_sources,
#    1116     output_gradients=output_gradients,
#    1117     sources_raw=flat_sources_raw,
#    1118     unconnected_gradients=unconnected_gradients)
#    1120 if not self._persistent:
#    1121   # Keep track of watched variables before setting tape to None
#    1122   self._watched_variables = self._tape.watched_variables()
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/tensorflow/python/eager/imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/tensorflow/python/eager/backprop.py:157, in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     155     gradient_name_scope += forward_pass_name_scope + "/"
#     156   with ops.name_scope(gradient_name_scope):
# --> 157     return grad_fn(mock_op, *out_grads)
#     158 else:
#     159   return grad_fn(mock_op, *out_grads)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/tensorflow/python/ops/math_grad.py:262, in _MeanGrad(op, grad)
#     259   output_shape = array_ops.shape(op.outputs[0])
#     260   factor = _safe_shape_div(
#     261       math_ops.reduce_prod(input_shape), math_ops.reduce_prod(output_shape))
# --> 262 return math_ops.truediv(sum_grad, math_ops.cast(factor, sum_grad.dtype)), None
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:7215, in raise_from_not_ok_status(e, name)
#    7213 def raise_from_not_ok_status(e, name):
#    7214   e.message += (" name: " + name if name is not None else "")
# -> 7215   raise core._status_to_exception(e) from None
#
# ResourceExhaustedError: {{function_node __wrapped__RealDiv_device_/job:localhost/replica:0/task:0/device:GPU:0}} failed to allocate memory [Op:RealDiv]
